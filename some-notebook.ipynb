# %%
import numpy as np
import pandas as pd
import xarray as xr
import cartopy as ccrs
from matplotlib import pyplot as plt

print("good to go")
# Out:
# good to go

# %%
import numpy as np
print(np.dtype('i2'), np.dtype('i2').itemsize, "bytes")
print(np.dtype('f8'), np.dtype('f8').itemsize, "bytes")
print(np.dtype('complex256'), np.dtype('complex256').itemsize, "bytes")
# Out:
# int16 2 bytes
# float64 8 bytes
# complex256 32 bytes

# %%
"😀".encode()
# Out:
# b'\xf0\x9f\x98\x80'

# %%
url = "https://data.nasa.gov/api/views/gh4g-9sfh/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(url)
df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
import xarray as xr
url = "http://iridl.ldeo.columbia.edu/expert/SOURCES/.NOAA/.NCEP/.CPC/.UNIFIED_PRCP/.GAUGE_BASED/.GLOBAL/.v1p0/.Monthly/.RETRO/.rain/dods"
# decode_times=False is required because the IRI Data Library uses non-standard encoding of times
ds = xr.open_dataset(url, decode_times=False)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (T: 324, Y: 360, X: 720)
# Coordinates:
#   * T        (T) float32 228.5 229.5 230.5 231.5 ... 548.5 549.5 550.5 551.5
#   * Y        (Y) float32 -89.75 -89.25 -88.75 -88.25 ... 88.25 88.75 89.25 89.75
#   * X        (X) float32 0.25 0.75 1.25 1.75 2.25 ... 358.2 358.8 359.2 359.8
# Data variables:
#     rain     (T, Y, X) float32 ...
# Attributes:
#     Conventions:  IRIDL

# %%
import pooch
POOCH = pooch.create(
    path=pooch.os_cache("2017_Antarctica_P3/CSARP_mvdr"),
    base_url="https://data.cresis.ku.edu/data/rds/2017_Antarctica_P3/CSARP_mvdr/20171124_03/",
    registry={
        "Data_img_02_20171124_03_020.mat": None,
    }
)

local_fname = POOCH.fetch("Data_img_02_20171124_03_020.mat")
local_fname
# Out:
# Downloading file 'Data_img_02_20171124_03_020.mat' from 'https://data.cresis.ku.edu/data/rds/2017_Antarctica_P3/CSARP_mvdr/20171124_03/Data_img_02_20171124_03_020.mat' to '/Users/davidlakes/Library/Caches/2017_Antarctica_P3/CSARP_mvdr'.
# '/Users/davidlakes/Library/Caches/2017_Antarctica_P3/CSARP_mvdr/Data_img_02_20171124_03_020.mat'

# %%
import h5py
f = h5py.File(local_fname)
list(f)
# Out:
# ['#refs#',
#  'Bottom',
#  'Data',
#  'Elevation',
#  'GPS_time',
#  'Heading',
#  'Latitude',
#  'Longitude',
#  'Pitch',
#  'Roll',
#  'Surface',
#  'Time',
#  'param_combine',
#  'param_csarp',
#  'param_records']

# %%
POOCH = pooch.create(
    path=pooch.os_cache("greenland_ice_sheet"),
    base_url="https://zenodo.org/record/4977910/files/",
    registry={
        "vel_2010-07-01_2011-06-31.nc": "md5:80ad1a3c381af185069bc032a6459745",
    }
)

fname = POOCH.fetch("vel_2010-07-01_2011-06-31.nc")
fname
# Out:
# Downloading file 'vel_2010-07-01_2011-06-31.nc' from 'https://zenodo.org/record/4977910/files/vel_2010-07-01_2011-06-31.nc' to '/Users/davidlakes/Library/Caches/greenland_ice_sheet'.
# '/Users/davidlakes/Library/Caches/greenland_ice_sheet/vel_2010-07-01_2011-06-31.nc'

# %%
ds = xr.open_dataset(fname)
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (x: 10018, y: 17946)
# Coordinates:
#   * x             (x) float64 -6.38e+05 -6.378e+05 ... 8.644e+05 8.646e+05
#   * y             (y) float64 -6.576e+05 -6.578e+05 ... -3.349e+06 -3.349e+06
# Data variables:
#     coord_system  |S1 ...
#     VX            (y, x) float32 ...
#     VY            (y, x) float32 ...
# Attributes: (12/27)
#     Conventions:               CF-1.6
#     Metadata_Conventions:      CF-1.6, Unidata Dataset Discovery v1.0, GDS v2.0
#     standard_name_vocabulary:  CF Standard Name Table (v22, 12 February 2013)
#     id:                        vel_final.t.nc
#     title:                     MEaSURES Antarctica Ice Velocity Map 450m spacing
#     product_version:
#     ...                        ...
#     time_coverage_start:       1995-01-01
#     time_coverage_end:         2016-12-31
#     project:                   NASA/MEaSUREs_UC-Irvine
#     creator_name:              J. Mouginot
#     comment:
#     license:                   No restrictions on access or use

# %%
ds = xr.open_dataset('diffusivity_AM2013.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 160, lon: 360)
# Coordinates:
#   * lat       (lat) float64 -79.5 -78.5 -77.5 -76.5 ... 76.5 77.5 78.5 79.5
#   * lon       (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Data variables:
#     K_OC_PSI  (lat, lon) float64 ...
#     K_OC_SST  (lat, lon) float64 ...
#     KMIN      (lat, lon) float64 ...
#     K_OC_LAT  (lat, lon) float64 ...

# %%
doi = "doi:10.5281/zenodo.10472337"
fname = "epa_air_quality_annual_summary.csv"
file_path = pooch.retrieve(
    url=f"{doi}/{fname}",
    known_hash="md5:492d926832edb025baaceb500850a445",
)
file_path
# Out:
# Downloading data from 'doi:10.5281/zenodo.10472337/epa_air_quality_annual_summary.csv' to file '/Users/davidlakes/Library/Caches/pooch/1a7f73318b3df408798606023e6552a8-epa_air_quality_annual_summary.csv'.
# '/Users/davidlakes/Library/Caches/pooch/1a7f73318b3df408798606023e6552a8-epa_air_quality_annual_summary.csv'

# %%
pd.read_csv(file_path).tail()
# Out:
# /var/folders/x1/bgmt0fwj3p78yqt5qw03mng40000gn/T/ipykernel_97674/3001410402.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(file_path).tail()
#         state_code  county_code  site_num  parameter_code  poc   latitude  \
# 2038705          6           13      1002           43802    3  38.006311
# 2038706         25           25        42           43291   11  42.329500
# 2038707          6           85      2009           43702    3  37.318435
# 2038708         13           89         2           88374    5  33.687970
# 2038709          6           19      5001           88101    1  36.819111
#
#           longitude  datum                   parameter_name sample_duration  \
# 2038705 -121.641918  WGS84                  Dichloromethane         24 HOUR
# 2038706  -71.082600  WGS84               23-Dimethylpentane         24 HOUR
# 2038707 -122.069705  WGS84                     Acetonitrile         24 HOUR
# 2038708  -84.290480  WGS84  OC1 CSN_Rev Unadjusted PM2.5 LC         24 HOUR
# 2038709 -119.717356  WGS84         PM2.5 - Local Conditions         24 HOUR
#
#          ... seventy_five_percentile fifty_percentile ten_percentile  \
# 2038705  ...                   0.000            0.000          0.000
# 2038706  ...                   0.100            0.100          0.100
# 2038707  ...                   0.000            0.000          0.000
# 2038708  ...                   0.304            0.134          0.036
# 2038709  ...                  15.900           10.200          5.700
#
#                local_site_name                               address  \
# 2038705          Bethel Island                 5551 BETHEL ISLAND RD
# 2038706  DUDLEY SQUARE ROXBURY                          HARRISON AVE
# 2038707  Cupertino Monta Vista                        22601 Voss Ave
# 2038708           South DeKalb  2390-B Wildcat Road Decatur GA 30034
# 2038709           Clovis-Villa                908 N VILLA AVE CLOVIS
#
#             state_name   county_name      city_name  \
# 2038705     California  Contra Costa  Bethel Island
# 2038706  Massachusetts       Suffolk         Boston
# 2038707     California   Santa Clara      Cupertino
# 2038708        Georgia        DeKalb            NaN
# 2038709     California        Fresno         Clovis
#
#                                  cbsa_name  date_of_last_change
# 2038705   San Francisco-Oakland-Hayward CA           2012-09-28
# 2038706      Boston-Cambridge-Newton MA-NH           2016-06-22
# 2038707  San Jose-Sunnyvale-Santa Clara CA           2014-04-29
# 2038708   Atlanta-Sandy Springs-Roswell GA           2016-03-08
# 2038709                          Fresno CA           2016-01-27
#
# [5 rows x 55 columns]
